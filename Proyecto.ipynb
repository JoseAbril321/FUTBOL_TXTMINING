# %%
import re
import unicodedata
import numpy as np
from sklearn.model_selection import train_test_split
from tensorflow.keras.preprocessing.text import Tokenizer
from tensorflow.keras.preprocessing.sequence import pad_sequences
import tensorflow as tf
from tensorflow.keras.callbacks import EarlyStopping
import pandas as pd

# Cargar el dataset
data = pd.read_csv('test.csv')

# Función para limpiar los subtítulos eliminando metadatos y normalizando los caracteres
def clean_subtitles(text):
    text = re.sub(r'WEBVTT.*\n', '', text)
    text = re.sub(r'Kind:.*\n', '', text)
    text = re.sub(r'Language:.*\n', '', text)
    text = re.sub(r'\[.*?\]', '', text)
    text = re.sub(r'\d{2}:\d{2}:\d{2}.\d{3} --> \d{2}:\d{2}:\d{2}.\d{3}', '', text)
    
    # Reemplazar tildes y mantener la ñ
    text = unicodedata.normalize('NFKD', text).encode('ASCII', 'ignore').decode('ASCII')
    
    # Convertimos letras acentuadas a letras normales (a, e, i, o, u)
    text = re.sub(r'á', 'a', text)
    text = re.sub(r'é', 'e', text)
    text = re.sub(r'í', 'i', text)
    text = re.sub(r'ó', 'o', text)
    text = re.sub(r'ú', 'u', text)
    
    # Eliminar espacios adicionales
    text = re.sub(r'\s+', ' ', text).strip()
    
    return text

# Aplicar la limpieza al dataset
data['Cleaned_Subtitles'] = data['Subtitles'].apply(clean_subtitles)

# %%
# Definir los patrones de eventos clave utilizando expresiones regulares
event_patterns = {
    'Goles': r'\b(gol|anotacion|marco|marcaron)\b',
    'Tarjetas Amarillas': r'\b(tarjeta amarilla|amonestacion|amarilla)\b',
    'Tarjetas Rojas': r'\b(tarjeta roja|expulsado|expulsion|expulsar|roja|expulsaron)\b',
    'Tiros de Esquina': r'\b(corner|tiro de esquina)\b',
    'Saques de Banda': r'\b(saque de banda)\b',
    'Faltas': r'\b(falta|infraccion|foul|faul)\b',
    'Penales': r'\b(penal|penalty)\b',
    'Posesión de balón': r'\b(posesion)\b',
    'Fueras de juego': r'\b(fuera de juego|offside)\b',
    'Tiros': r'\b(tiro|disparo)\b'
}

# Función para etiquetar un fragmento de texto con el evento correspondiente
def label_events(text):
    labels = []
    for event, pattern in event_patterns.items():
        if re.search(pattern, text, re.IGNORECASE):
            labels.append(event)
    return labels

# Aplicar la función para generar etiquetas
data['Event_Labels'] = data['Cleaned_Subtitles'].apply(label_events)

# Convertir las listas de eventos en una única etiqueta simplificada por fragmento
def simplify_labels(event_list):
    if 'Goles' in event_list:
        return 0  # Goles
    elif 'Tarjetas Amarillas' in event_list:
        return 1  # Tarjeta Amarilla
    elif 'Tarjetas Rojas' in event_list:
        return 2  # Tarjeta Roja
    elif 'Tiros de Esquina' in event_list:
        return 3  # Tiros de Esquina
    elif 'Faltas' in event_list:
        return 4  # Faltas
    elif 'Penales' in event_list:
        return 5  # Penales
    else:
        return 6  # Ningún evento

data['Simplified_Labels'] = data['Event_Labels'].apply(simplify_labels)

# Función para detectar eventos en un fragmento de texto
def detect_events(text):
    event_counts = {event: 0 for event in event_patterns}  # Inicializamos el conteo de eventos
    for event, pattern in event_patterns.items():
        matches = re.findall(pattern, text, re.IGNORECASE)
        event_counts[event] += len(matches)  # Contamos cuántas veces aparece cada evento
    return event_counts

# %%
# Dividimos los datos en entrenamiento y prueba
train_data, test_data = train_test_split(data, test_size=0.2, random_state=42)

# Aumentamos el tamaño máximo de secuencias para capturar más contexto
maxlen = 200  # Aumentamos el tamaño máximo de la secuencia para capturar más contexto

# Tokenización del texto
tokenizer = Tokenizer(num_words=10000)
tokenizer.fit_on_texts(train_data['Cleaned_Subtitles'])

train_sequences = tokenizer.texts_to_sequences(train_data['Cleaned_Subtitles'])
test_sequences = tokenizer.texts_to_sequences(test_data['Cleaned_Subtitles'])

# Rellenamos las secuencias para que tengan la misma longitud
X_train = pad_sequences(train_sequences, maxlen=maxlen)
X_test = pad_sequences(test_sequences, maxlen=maxlen)

# Convertimos las etiquetas en arrays
y_train = train_data['Simplified_Labels']
y_test = test_data['Simplified_Labels']

# Definimos el modelo LSTM con dropout
model = tf.keras.Sequential([
    tf.keras.layers.Embedding(input_dim=10000, output_dim=128, input_length=maxlen),
    tf.keras.layers.LSTM(256, return_sequences=False),
    tf.keras.layers.Dropout(0.3),  # Añadimos dropout después de la LSTM
    tf.keras.layers.Dense(128, activation='relu'),
    tf.keras.layers.Dropout(0.3),  # Añadimos dropout antes de la capa final
    tf.keras.layers.Dense(7, activation='softmax')  # 7 clases de eventos
])

# Compilamos el modelo
model.compile(optimizer='adam', loss='sparse_categorical_crossentropy', metrics=['accuracy'])

# Definimos EarlyStopping para detener el entrenamiento cuando el modelo deja de mejorar
early_stopping = EarlyStopping(monitor='val_loss', patience=3, restore_best_weights=True)

# Entrenamos el modelo con más épocas y early stopping
history = model.fit(X_train, y_train, 
                    epochs=100,  # Aumentamos las épocas
                    validation_data=(X_test, y_test), 
                    batch_size=32, 
                    callbacks=[early_stopping])
# Out:
# Epoch 1/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 3s 231ms/step - accuracy: 0.5922 - loss: 1.9287 - val_accuracy: 1.0000 - val_loss: 1.8231
# Epoch 2/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9758 - loss: 1.7317 - val_accuracy: 1.0000 - val_loss: 0.0829
# Epoch 3/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 121ms/step - accuracy: 0.9797 - loss: 0.2041 - val_accuracy: 1.0000 - val_loss: 2.9818e-04
# Epoch 4/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 120ms/step - accuracy: 0.9875 - loss: 0.1114 - val_accuracy: 1.0000 - val_loss: 3.4940e-04
# Epoch 5/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 119ms/step - accuracy: 0.9836 - loss: 0.1324 - val_accuracy: 1.0000 - val_loss: 0.0063
# Epoch 6/100
# 3/3 ━━━━━━━━━━━━━━━━━━━━ 0s 116ms/step - accuracy: 0.9758 - loss: 0.1353 - val_accuracy: 1.0000 - val_loss: 0.0662

# %%
# Función para convertir predicciones de modelos en eventos legibles
def prediction_to_event(pred):
    event_index = np.argmax(pred)
    event_mapping = {0: 'Goles', 1: 'Tarjetas Amarillas', 2: 'Tarjetas Rojas', 3: 'Tiros de Esquina', 4: 'Faltas', 5: 'Penales', 6: 'Ningún evento'}
    return event_mapping[event_index]

# Aplicamos el modelo a nuevas narraciones
predictions = model.predict(X_test)

# Función mejorada para asignar los eventos detectados a Equipo 1 y Equipo 2
def assign_events_to_teams(text, team1_name='Equipo 1', team2_name='Equipo 2'):
    team1_stats = {event: 0 for event in event_patterns}
    team2_stats = {event: 0 for event in event_patterns}
    
    # Procesamos el texto en oraciones o fragmentos
    sentences = text.split('.')
    
    # Alternamos entre los equipos para asignar los eventos
    current_team = 1
    
    for sentence in sentences:
        event_counts = detect_events(sentence)
        
        # Asignar los eventos al equipo correspondiente
        if current_team == 1:
            for event, count in event_counts.items():
                team1_stats[event] += count
            current_team = 2  # Alternamos al Equipo 2
        else:
            for event, count in event_counts.items():
                team2_stats[event] += count
            current_team = 1  # Volvemos al Equipo 1
    
    return team1_stats, team2_stats

# Generar estadísticas para las narraciones de prueba
for i in range(5):  # Revisamos las primeras 5 narraciones para verificar las predicciones y las estadísticas
    print(f"Narración: {test_data['Cleaned_Subtitles'].iloc[i]}")
    print(f"Predicción del evento: {prediction_to_event(predictions[i])}")
    team1_stats, team2_stats = assign_events_to_teams(test_data['Cleaned_Subtitles'].iloc[i])
    print(f'Estadísticas Equipo 1: {team1_stats}')
    print(f'Estadísticas Equipo 2: {team2_stats}')
    print('---')
# Out:
# 1/1 ━━━━━━━━━━━━━━━━━━━━ 0s 167ms/step
#
 libre, pero a medida que avance el juego creo que sera Mas bien un cuatro o cinco, es el habitual lateral plano del Everton, pero es en el mediocampo donde Pierre es un area clave para ellos y ahi es donde se ganara o perdera el juego. Los coches lideres menos afectados por Thomas Graham Erson. lo hace muy bien, se mantendra justo delante del piso trasero y lo protegera. Watson, un armador artistico jugara cerca de el, aunque lo hara apretado en el mediocampo tres y McFadden en Kilburn hara un cinco cuando no tengan el balon. cuando reciban el balon y esta es mi gran preocupacion esta noche, tienen que levantarse y ayudar a James Beattie. No pueden dejar que se quede aislado cuando reciba el balon, tiene que sujetarlo, Bueno, el momento del gran hombre siempre ha sido impecable, ...
# Predicción del evento: Goles
# Estadísticas Equipo 1: {'Goles': 11, 'Tarjetas Amarillas': 1, 'Tarjetas Rojas': 0, 'Tiros de Esquina': 1, 'Saques de Banda': 0, 'Faltas': 2, 'Penales': 0, 'Posesión de balón': 7, 'Fueras de juego': 4, 'Tiros': 4}
# Estadísticas Equipo 2: {'Goles': 11, 'Tarjetas Amarillas': 1, 'Tarjetas Rojas': 1, 'Tiros de Esquina': 1, 'Saques de Banda': 0, 'Faltas': 2, 'Penales': 1, 'Posesión de balón': 4, 'Fueras de juego': 3, 'Tiros': 3}
# ---
# Narración: WEBVTT Kind: captions Language: es el partido que esta a punto de comenzar el napoles con camiseta azul que va a quedar a la izquierda de sus imagenes en milan a su derecha comenzo el partido en el estadio san paolo con lleno absoluto para ver a estos dos grandes equipos de la serie de la liga italiana y la primera accion que queria protagonizar marco van basten con esa pelota que finalmente recupera en napoles en falta un marco van basten que esta en un gran momento de forma que lleva cuatro goles en el campeonato y muchos de ellos han situado al mirar en el momento en el que esta con nueve puntos a dos del segundo el inter de milan y destacado totalmente la liga italiana el napoles por su parte por su parte estaba jugando bastante mal lo esta haciendo un buen comienzo de temporada lleva solo cuatro puntos y sin duda tiene que ganar este partido como sea para no distanciarse de la cabeza de la clasificacion el que jugo fue evans y a la posicion de maldini el balon colgado nos llega a rascar cabecear el balon que se recupera para el napoles gal y el guardameta del conjunto napolitano diego armando maradona en accion reclama mas manos del jugador milanes el astro argentino no senalo nada al colegiado y la posicion el balon d alessandro costacurta hacia pasar lee se puso en apuros en esta ocasion el defensor a su guardameta el que juegas maldini recuperara el napoles de nuevo maradona una vez mas el centro del campo en milan con drive car jugando con costacurta y el balon colgado finalmente de nuevo el napoles en el ataque la pelota que nuevamente va a recuperar el milan por mediacion de arriesgar el balon finalmente se va a perder por la linea de banda pelota para el napoles ahi tenemos a ferrara aunque sera finalmente de napoli el que haga ese lanzamiento de banda jugo a la posicion y aleman y la falta que senala el colegiado sobre ricardo aleman ahi esta ricardo alem a un hombre que ha sido multado por la federacion brasilena de futbol por unas duras declaraciones con respecto al pasado mundial en el que lazaro niega a seleccionador hay que recordar que lanzaron y ha decidido no llamar a estos jugadores que estan yendo a liga italiana y en todas las competiciones europeas hasta el momento del napoles esta jugando mejor esta aplicando un poco mas y el milan le vemos un poco la linea de atras que hacen zona como siempre presiona pero esta bastante mas atras que de costumbre napoles esta llevando la iniciativa del partido la pelota la va a recuperar en coche a ti el balon colgado del coche a ti de espejo costacurta raiz card que recupera para el milan va a jugar en corto a la posicion de tassotti tassotti de nuevo con rice card no esta adelantada hacia angellotti el balon de ancelotti que no lo pudo dominar disenar al colegiado frank falta del propio ancelotti y cartulina amarilla la primera tarjeta amarilla del partido que ha visto ancelotti por esa entrada sobre ferrara un ancelotti que esta jugando bastante mas adelantado que de costumbre esta intentando presionar en la salida del napoles con la pelota controlada y el milan ha dejado solo en punta van basten y de mediapunta gullit un sistema bastante sencillo que utilizas aqui casi siempre sobre todo cuando juegan fuera de casa jugando de nuevo al milan por mediacion de ivan y bani que va a jugar hacia maldini en corto con ancelotti con un largo de ancelotti para rascar y va a recuperar nuevamente el napoles ha senalado falta del propio rijkaard o ademas el que puso el valor en el movimiento la pelota para venturin en de nuevo el propio franzini el que ha caido al suelo script ha ensenado nada en esta ocasion el colegiado cerrar a balon largo de ferrara buscando la posicion de caracas no llego antes pasarle y detuvo el esferico estamos ya en el minuto 5 de la primera parte de este partido de la serie de la liga italiana que les ofrece canal+ napoles 0 milan 0 jugando ancelotti para el milan y la pelota impulsada finalmente por pares y que se pierde por la linea de  ...
# Predicción del evento: Goles
# Estadísticas Equipo 1: {'Goles': 61, 'Tarjetas Amarillas': 9, 'Tarjetas Rojas': 0, 'Tiros de Esquina': 9, 'Saques de Banda': 9, 'Faltas': 51, 'Penales': 2, 'Posesión de balón': 0, 'Fueras de juego': 10, 'Tiros': 21}
# Estadísticas Equipo 2: {'Goles': 0, 'Tarjetas Amarillas': 0, 'Tarjetas Rojas': 0, 'Tiros de Esquina': 0, 'Saques de Banda': 0, 'Faltas': 0, 'Penales': 0, 'Posesión de balón': 0, 'Fueras de juego': 0, 'Tiros': 0}
# ---
# Narración: WEBVTT Kind: captions Language: es Recogido en los quioscos cada semana uno real. guia sobre tarjetas y disquetes para programa videojuegos y manana lo hare compra y hazte presidente de los estados tortellini galacticos Puff una tradicion un amor este era el comercial pero la paffa dijo basta con estas historias La gente finge los esloganes que quedan. Hablo del producto y tenian razon. Hojaldre muy fino Hojaldre casi fino impalpable muchos rellenos diferentes Cuestan un poco mas pero es posible. ingredientes Y ahora un amistoso de lujo en vivo desde comentario aov del partido de futbol de Holanda Italia comentarista Bruno Pizzul director Nazareno Percebes Nazareno buenos noche do Sr. Escucha Buenas noches. conectado en vivo con el estadio heindoven en Holanda donde va a tener comienza el encuentro internacional Amistoso de futbol entre las selecciones nacionales de Holanda amigable lujo eitalia eso si ella deberia haber desempenado el papel final de la temporada pasada por razones el calendario se ha movido a hoy no hace falta decir que es una prueba particularmente desafiante para el formacion de sacos que disputa esta noche el ultimo partido amistoso en poco mas un mes en Cagliari jugaremos contra Suiza y ya sera una carrera valida para el clasificacion para el campeonato mundial de Estados Unidos te lo dare todo inmediatamente formacion de Italia ves los Azzurri Marcheggiani alineado en el centro del campo trae a los defensores Mannini Costacurta Maldini y Chiara en el centro del campo estuvieron geniales Albertini y Devani Lentini Vialli y Baggio adelante mientras ve el formacion holandesa que tiene reen Gullit en el campo y por el resto sigue el despliegue tactico habitual esta manana ultima sesion de formacion y Giampiero Galeazzi ha declaraciones digamos una exposicion de la de la Formacion Pero este l mediocampo tan fuerte la eleccion de Evani apoyando al centro del campo italiano Quizas el mas adecuado pero el que nosotros jugaremos con tres jugadores en ataque que seran Lenini y Vialli y Roberto Baggio y por eso intentamos poner un mediocampo que al menos danos una garantia de continuidad de accion entonces tenemos cuatro posibilidad de cuatro sustituciones por lo tanto es casi seguro que Roberto Donadoni jugara entonces en la segunda parte en lugar de uno de estos tres mediocampistas Cuanto vale esta prueba? en terminos numericos vale mucho para Vale mucho la pena seguir en ese discurso de aprendizaje mejora que hemos comenzado hace unos meses y que este partido es una coincidencia inapropiada bajo este punto de vista porque ha llegado demasiado lejos pero pronto nos permitira acelerar Este aprendiendo hablo de ti bueno Hemos escuchado las declaraciones de nuestro comisario tecnico ver Lo despliegue de los azzurri a los que les gusta alli Dije al principio al menos si. aunque presentan un 4-3-3 obviamente Lentini y Baggio volveran a dar apoyo a los centrocampistas Per respecto a Holanda a considerar uno de los equipos mas fuertes del mundo Tiene en la porteria y luego hay tres defensores. vanar kuman y debur en el centro del campo vard Ber de tip Gullit vanen Es inutil decir que la presencia de los tres jugadores de Milan en particular de Gulli Obligado a subir a las gradas cobra importancia de caracter si queremos incluso polemicos Hay que decir que no hay audiencia particularmente grande Yo estimaria alrededor de 10.000 personas G nacionales ya se han realizado y ahora El inicio se retrasa un poco. Por que? se entregan premios y reconocimientos premios a algunos jugadores holandeses que abandonaron el carrera se trata del portero Van Bren del defensor van kelen y mata todos los elementos que aprendimos sobre y apreciar en competiciones internacionales de la seleccion holandesa que ves mientras tanto Fran Reard enmarcado sera el punto de apoyo del Centrocampista holandes una seleccion nacional de Holanda que ha conocido un pellizco de amargura en los ultimos campeonatos de Europa en la fase final tras h ...
# Predicción del evento: Goles
# Estadísticas Equipo 1: {'Goles': 22, 'Tarjetas Amarillas': 0, 'Tarjetas Rojas': 0, 'Tiros de Esquina': 1, 'Saques de Banda': 3, 'Faltas': 8, 'Penales': 1, 'Posesión de balón': 0, 'Fueras de juego': 7, 'Tiros': 9}
# Estadísticas Equipo 2: {'Goles': 20, 'Tarjetas Amarillas': 0, 'Tarjetas Rojas': 0, 'Tiros de Esquina': 2, 'Saques de Banda': 1, 'Faltas': 5, 'Penales': 1, 'Posesión de balón': 3, 'Fueras de juego': 10, 'Tiros': 15}
# ---
# Narración: WEBVTT Kind: captions Language: es hola, vale la pena hablar de ello? en el estadio san siro estadio giuseppe Meazza agotado tal vez ser diferente cuando el destino se decide entonces cuando se decide lugar el campeonato esta en sus manos es el destino en manos del equipo local en manos del Milan Quien lleva a Roma a San Siro? su unico competidor el unico perseguidor mas seis Milan tiene puntos Este es exactamente el tipo de cerdo Carlo Ancelotti frente a Fabio Capello tres rondas hasta el final del campeonato italiano y Despues del partido cara a cara, los equipos tendran que jugar un partido dos veces mas en casa solo en el camino, no con los mas fuertes rivales resulto que esta temporada cintura que en general puedes para clubes italianos jugo bien en la liga de campeones Los periodistas italianos ya estaban alborotados. y a esta liga la llamaron bola final Partido de campeones que podria decorar. campeonato de liga pero por ahora condecora solo una serie pero solo hay suficiente espacio aqui tranquilo y calmado pero como se informo Y la alianza kismi antes del partido fueron Los disturbios fueron enfrentamientos entre Seguimos siendo fanaticos de Milan y Roma. expresar esperanza de que todavia habra futbol solo una camiseta yo tampoco estare nervioso directores Las transmisiones que entiendo son Milan. st y estan preocupados antes del partido Probablemente los futbolistas tambien esten preocupados por la situacion. bastante obvio en caso de victoria Milan hoy se convierte en 17 veces campeon de italia cuidadoso y carletto Carlo Ancelotti Carletto asi x carinosamente lo llaman en italia conferencia de prensa de ayer dijo que en al final podemos jugar hasta el empate al gotico desde un punto de vista estrategico carly quien tiene razon y como mas seis puntos entonces un handicap en caso de empate se retendra el salario terminar y recuperar estos seis puntos dos los tours restantes ya son algo de Areas de fantasia, pero los gitanos de hoy. Lo digo en serio, la Roma esta lista hoy. dar pelea, pues la pelea ya va, yo soy asi Entiendo que hay petardos en las gradas unos petardos truenan a nuestra izquierda con tu tribuna invitada en donde se encuentran los tifosi roma bien y se iluminan alli o en directo y en sentido figurado ya tengo prisa El juego ha comenzado, te presento a nuevos jugadores Los equipos comenzaran por Milan Dido, puerta 12. numero siguiente por respeto a los muchos fans calcio italiano Puede que no mencione los numeros debajo que juegan todos los demas jugadores de futbol, pero porque el partido de hoy es especialmente creo Que tiene que ver con que la esposa y los hijos tengan el dia libre? mitad fuerte de la humanidad constituyendo la gran mayoria nuestros espectadores de hoy tambien estan junto con por los hermanos de sus maridos y asi sucesivamente esta viendo este partido por lo tanto para ustedes, queridas senoras, todos los numeros Nombrare jugadores de futbol, tal vez tu no los nombraras a todos ya sabes, pero excepto Francesco Totti si Estamos hablando de nuestros hermosos espectadores. todos lo conocen en persona asi que con nosotros antes asi jugara de derecha a izquierda 19 numero solo kurta dos central el defensor es 3 alessandro nesta y capitan numero tres gigolo aisulu aqui tienes alimentar directamente junto con sus pero los hermanos decidieron primavera como siempre todavia hago 1 Aqui pero hasta mas dos espadas menos que eso pero no es la lampara la que lo persigue, que tambien es tati Y cuantos goles marco? campeonato shevchenko tal vez valga la pena todos esos 20 extra cual tengo confianza en mi mismo dota te lo mostrara todavia ahi por que muy gentil orina gastar por etiqueta y . zolino que moreton Mesina sin dudarlo presenta al defensa frances todavia necesitas yeso de mostaza con los ingredientes paramos en nosotros paramos en dia de la paloma ella es capitana del milan el el numero tres y asi sucesivamente Los centrocampistas son el numero ocho de Gattuso 21 1 20 sidor 22 lo  ...
# Predicción del evento: Goles
# Estadísticas Equipo 1: {'Goles': 0, 'Tarjetas Amarillas': 2, 'Tarjetas Rojas': 0, 'Tiros de Esquina': 0, 'Saques de Banda': 0, 'Faltas': 2, 'Penales': 1, 'Posesión de balón': 0, 'Fueras de juego': 0, 'Tiros': 6}
# Estadísticas Equipo 2: {'Goles': 9, 'Tarjetas Amarillas': 1, 'Tarjetas Rojas': 1, 'Tiros de Esquina': 0, 'Saques de Banda': 0, 'Faltas': 1, 'Penales': 2, 'Posesión de balón': 0, 'Fueras de juego': 0, 'Tiros': 4}
# ---

# %%
team1_stats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 1
# ----> 1 team1_stats
#
# NameError: name 'team1_stats' is not defined

# %%
team2_stats
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[2], line 1
# ----> 1 team2_stats
#
# NameError: name 'team2_stats' is not defined
